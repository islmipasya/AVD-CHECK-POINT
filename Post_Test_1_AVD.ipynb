# %%
import pandas as pd

# %%
from google.colab import drive

# %%
path = '/content/drive/MyDrive/Data AVD/tourism_dataset_5000 (2).csv'

# %%
df = pd.read_csv(path)

# %%
df.head(30)
# Out:
#     Tourist ID  Age                                Interests  \
# 0            1   48       ['Architecture', 'Art', 'History']
# 1            2   37                   ['Cultural', 'Nature']
# 2            3   43       ['History', 'Art', 'Architecture']
# 3            4   46      ['Cultural', 'Art', 'Architecture']
# 4            5   53                  ['Architecture', 'Art']
# 5            6   50  ['Architecture', 'History', 'Cultural']
# 6            7   61              ['Architecture', 'History']
# 7            8   23             ['Cultural', 'Architecture']
# 8            9   34                      ['Cultural', 'Art']
# 9           10   61               ['Nature', 'Architecture']
# 10          11   27               ['Nature', 'Architecture']
# 11          12   37                             ['Cultural']
# 12          13   45   ['Nature', 'Cultural', 'Architecture']
# 13          14   61                             ['Cultural']
# 14          15   60      ['Cultural', 'Architecture', 'Art']
# 15          16   50                             ['Cultural']
# 16          17   59                             ['Cultural']
# 17          18   18                   ['Nature', 'Cultural']
# 18          19   24                              ['History']
# 19          20   63               ['Nature', 'Architecture']
# 20          21   45                         ['Architecture']
# 21          22   62        ['Nature', 'History', 'Cultural']
# 22          23   65                   ['Nature', 'Cultural']
# 23          24   53                             ['Cultural']
# 24          25   26                             ['Cultural']
# 25          26   63                        ['Nature', 'Art']
# 26          27   24            ['Nature', 'Art', 'Cultural']
# 27          28   20                              ['History']
# 28          29   36                               ['Nature']
# 29          30   49    ['Nature', 'History', 'Architecture']
#
#     Preferred Tour Duration  Accessibility            Site Name  \
# 0                         5          False         Eiffel Tower
# 1                         6          False            Colosseum
# 2                         6           True         Machu Picchu
# 3                         8          False            Colosseum
# 4                         5           True            Colosseum
# 5                         4          False         Machu Picchu
# 6                         7          False         Eiffel Tower
# 7                         5          False         Eiffel Tower
# 8                         5           True            Colosseum
# 9                         5          False            Colosseum
# 10                        4          False         Eiffel Tower
# 11                        3           True         Eiffel Tower
# 12                        8           True         Eiffel Tower
# 13                        8           True            Colosseum
# 14                        4           True         Eiffel Tower
# 15                        7          False         Eiffel Tower
# 16                        7           True            Taj Mahal
# 17                        6           True         Machu Picchu
# 18                        5          False            Taj Mahal
# 19                        8          False            Colosseum
# 20                        6           True         Machu Picchu
# 21                        7           True            Colosseum
# 22                        8           True  Great Wall of China
# 23                        6           True            Taj Mahal
# 24                        8           True            Taj Mahal
# 25                        3          False            Colosseum
# 26                        3           True            Taj Mahal
# 27                        5          False         Eiffel Tower
# 28                        7           True  Great Wall of China
# 29                        6           True         Eiffel Tower
#
#                                         Sites Visited  Tour Duration  \
# 0   ['Eiffel Tower', 'Great Wall of China', 'Taj M...              7
# 1                             ['Great Wall of China']              1
# 2                                    ['Eiffel Tower']              2
# 3                       ['Machu Picchu', 'Taj Mahal']              5
# 4   ['Machu Picchu', 'Taj Mahal', 'Great Wall of C...              7
# 5   ['Great Wall of China', 'Eiffel Tower', 'Colos...              4
# 6          ['Eiffel Tower', 'Colosseum', 'Taj Mahal']              6
# 7                                       ['Colosseum']              2
# 8   ['Great Wall of China', 'Eiffel Tower', 'Colos...              6
# 9          ['Colosseum', 'Taj Mahal', 'Machu Picchu']              6
# 10         ['Machu Picchu', 'Colosseum', 'Taj Mahal']              6
# 11                      ['Colosseum', 'Machu Picchu']              5
# 12  ['Machu Picchu', 'Eiffel Tower', 'Great Wall o...              6
# 13                                   ['Eiffel Tower']              1
# 14                      ['Taj Mahal', 'Eiffel Tower']              6
# 15  ['Great Wall of China', 'Machu Picchu', 'Colos...              8
# 16            ['Great Wall of China', 'Machu Picchu']              3
# 17                      ['Eiffel Tower', 'Colosseum']              6
# 18         ['Colosseum', 'Eiffel Tower', 'Taj Mahal']              6
# 19                            ['Great Wall of China']              2
# 20                                      ['Taj Mahal']              2
# 21      ['Machu Picchu', 'Eiffel Tower', 'Taj Mahal']              5
# 22                                      ['Colosseum']              3
# 23            ['Machu Picchu', 'Great Wall of China']              6
# 24                   ['Machu Picchu', 'Eiffel Tower']              3
# 25  ['Colosseum', 'Eiffel Tower', 'Great Wall of C...              6
# 26                   ['Machu Picchu', 'Eiffel Tower']              4
# 27  ['Colosseum', 'Eiffel Tower', 'Great Wall of C...              4
# 28  ['Taj Mahal', 'Great Wall of China', 'Eiffel T...              8
# 29               ['Taj Mahal', 'Great Wall of China']              2
#
#     Route ID  Tourist Rating  System Response Time  Recommendation Accuracy  \
# 0       1000             1.6                  3.73                       97
# 1       2000             2.6                  2.89                       90
# 2       3000             1.7                  2.22                       94
# 3       4000             2.0                  2.34                       92
# 4       5000             3.7                  2.00                       96
# 5       6000             2.2                  3.74                       99
# 6       7000             4.1                  4.66                       93
# 7       8000             2.8                  4.84                       91
# 8       9000             4.0                  1.54                       95
# 9      10000             3.8                  3.59                       95
# 10     11000             3.2                  4.48                       99
# 11     12000             1.7                  2.63                      100
# 12     13000             1.8                  3.47                      100
# 13     14000             4.3                  3.48                       91
# 14     15000             2.9                  2.82                       94
# 15     16000             1.2                  4.44                       91
# 16     17000             2.1                  2.12                       95
# 17     18000             2.7                  3.63                      100
# 18     19000             2.6                  2.63                       86
# 19     20000             2.7                  4.79                       92
# 20     21000             2.8                  2.75                       94
# 21     22000             3.3                  2.65                       96
# 22     23000             4.2                  1.97                       88
# 23     24000             3.0                  4.02                       97
# 24     25000             2.4                  3.42                       90
# 25     26000             1.0                  4.09                       93
# 26     27000             2.0                  4.62                       87
# 27     28000             2.2                  1.61                       95
# 28     29000             4.1                  4.57                       91
# 29     30000             4.4                  2.18                       95
#
#     VR Experience Quality  Satisfaction
# 0                     4.5             3
# 1                     4.5             3
# 2                     4.7             3
# 3                     4.7             3
# 4                     4.8             4
# 5                     4.5             3
# 6                     4.5             4
# 7                     4.9             3
# 8                     4.4             4
# 9                     4.7             4
# 10                    4.2             3
# 11                    4.6             3
# 12                    4.5             3
# 13                    4.4             4
# 14                    4.2             3
# 15                    4.2             3
# 16                    4.3             3
# 17                    4.4             3
# 18                    4.7             3
# 19                    4.8             3
# 20                    4.7             3
# 21                    4.0             3
# 22                    5.0             4
# 23                    4.4             3
# 24                    4.7             3
# 25                    4.3             3
# 26                    4.5             3
# 27                    4.5             3
# 28                    4.6             4
# 29                    4.9             4

# %% [markdown]
# ## **Business Understanding**

# %% [markdown]
# 1. Business Objective
#
#     Tujuan dari proyek ini adalah meningkatkan kualitas layanan wisata dari sistem rekomendasi supaya wisatawan bisa merasa lebih puas. Dari insight yang ada, kebanyakan wisatawan hanya merasa “cukup puas”, artinya sistem sudah berjalan, tapi belum bisa bikin pengalaman wisata terasa maksimal. Kalau kepuasan wisatawan bisa ditingkatkan, maka peluang wisatawan untuk pakai layanan lagi juga lebih besar, dan citra layanan wisata jadi lebih baik.

# %% [markdown]
# 2. Assess Situation
#
#     Saat ini sistem punya data yang cukup lengkap tentang wisatawan, seperti minat, durasi tur, rating, kualitas VR, akurasi rekomendasi, dan response time. Tapi hasilnya menunjukkan kepuasan wisatawan masih dominan di level “cukup”. Ini bisa jadi karena rekomendasinya belum sesuai harapan, sistemnya kurang cepat, atau pengalaman VR-nya belum konsisten. Kalau ini dibiarkan, wisatawan bisa bosan dan memilih layanan lain yang lebih memuaskan.

# %% [markdown]
# 3. Analytic Goals Project Plan
#
#     Tujuan analisisnya adalah mencari tahu faktor apa yang paling bikin wisatawan belum sampai level “sangat puas”. Dari data kita ingin melihat apakah kepuasan dipengaruhi oleh akurasi rekomendasi, response time, kualitas VR, atau faktor lain. Selain itu analisis ini juga bisa dipakai untuk membuat model prediksi kepuasan, supaya sistem bisa tahu wisatawan mana yang berpotensi kurang puas dan bisa diperbaiki dari awal Setelah itu data dibersihkan dan disiapkan supaya gampang dianalisis. Lalu dilakukan analisis hubungan antara kepuasan dengan variabel lain seperti akurasi rekomendasi, kualitas VR, dan response time. Setelah pola ditemukan, dibuat model prediksi kepuasan dan dievaluasi hasilnya dan Terakhir dibuatlah rekomendasi perbaikan sistem supaya kepuasan wisatawan bisa meningkat
